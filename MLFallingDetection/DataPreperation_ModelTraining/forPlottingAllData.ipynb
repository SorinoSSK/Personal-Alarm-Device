# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "FallDataExport2"

# %%
df = pd.read_csv('../DataFile/' + filename + '.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df = df.reset_index()
display(df)

plt.plot(df['index'], df['Norm'])
# Out:
#          index  accX  accY  accZ                timestamp      Norm  label  \
# 0            0  0.03  0.00 -0.97  2024-03-22 15:59:41.181  0.970464      0
# 1            1  0.02  0.05 -0.94  2024-03-22 15:59:41.197  0.941541      0
# 2            2 -0.02  0.01 -1.00  2024-03-22 15:59:41.201  1.000250      0
# 3            3 -0.05  0.01 -0.99  2024-03-22 15:59:41.202  0.991312      0
# 4            4  0.01  0.02 -1.01  2024-03-22 15:59:41.249  1.010247      0
# ...        ...   ...   ...   ...                      ...       ...    ...
# 206908  206908  0.85 -0.38  0.23  2024-03-22 15:59:02.460  0.959062      0
# 206909  206909  0.89 -0.37  0.25  2024-03-22 15:59:02.505  0.995741      0
# 206910  206910  0.93 -0.36  0.25  2024-03-22 15:59:02.509  1.028105      0
# 206911  206911  0.98 -0.36  0.23  2024-03-22 15:59:02.513  1.069065      0
# 206912  206912  1.00 -0.27  0.21  2024-03-22 15:59:02.544  1.056882      0
#
#          level_0
# 0            NaN
# 1            NaN
# ...
